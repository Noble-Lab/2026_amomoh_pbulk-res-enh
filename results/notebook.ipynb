# %%
import sys
sys.path.insert(0, "../src")
from scHiC_subsample_ssim import run_all_subsample_sweeps

all_results = run_all_subsample_sweeps(
    matrices_root = "../results/matrices",
    pbulk_root = "../results/pseudo_bulk",
    bin_sizes = [1000000, 500000, 250000],
    n_replicates = 10,
    seed = 42  # fixed seed -- same subsets drawn every time this cell reruns
)
# Out:
# ---- BJ @ 1mb ----
# ---- BJ @ 500kb ----
# ---- BJ @ 250kb ----
# ---- K562 @ 1mb ----
# ---- K562 @ 500kb ----
# ---- K562 @ 250kb ----
# ---- eHAP @ 1mb ----
# ---- eHAP @ 500kb ----
# ---- eHAP @ 250kb ----
# ---- GM12878 @ 1mb ----
# ---- GM12878 @ 500kb ----
# ---- GM12878 @ 250kb ----
